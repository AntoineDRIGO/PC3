# %% [markdown]
# # Primero Hacer esta tarea: Integre los archivos que están el folder comprimido (appendData.zip)

# %%
import pandas as pd
#I start with the table "level1"
url = 'https://github.com/AntoineDRIGO/PC3/raw/main/level1.csv'

# I read csv precising "," is the way to get decimals
level1 = pd.read_csv(url, sep=';', decimal=',', encoding='ISO-8859-1')
level1
# Out:
#     HDI rank                 Country  Human Development Index (HDI)   \
# 0          1             Switzerland                           0.962
# 1          2                  Norway                           0.961
# 2          3                 Iceland                           0.959
# 3          4  Hong Kong, China (SAR)                           0.952
# 4          5               Australia                           0.951
# ..       ...                     ...                             ...
# 61        62                Malaysia                           0.803
# 62        63                 Georgia                           0.802
# 63        63               Mauritius                           0.802
# 64        63                  Serbia                           0.802
# 65        66                Thailand                           0.800
#
#     Life expectancy at birth  Expected years of schooling  \
# 0                       84.0                         16.5
# ...

# %%
#I rename the columns
level1 = level1.rename(columns={
    'HDI rank': 'HDI_rank_2021','Human Development Index (HDI)':'HDI','Life expectancy at birth':'Life_expectancy',
    'Expected years of schooling': 'School_level_expected','Mean years of schooling':'Mean_school_level',
    'Gross national income (GNI) per capita':'GNI','GNI per capita rank minus HDI rank': 'GNI_rank'})
level1
# Out:
#     HDI_rank_2021                 Country  Human Development Index (HDI)   \
# 0               1             Switzerland                           0.962
# 1               2                  Norway                           0.961
# 2               3                 Iceland                           0.959
# 3               4  Hong Kong, China (SAR)                           0.952
# 4               5               Australia                           0.951
# ..            ...                     ...                             ...
# 61             62                Malaysia                           0.803
# 62             63                 Georgia                           0.802
# 63             63               Mauritius                           0.802
# 64             63                  Serbia                           0.802
# 65             66                Thailand                           0.800
#
#     Life_expectancy  School_level_expected  Mean_school_level     GNI  \
# ...

# %%
print(level1.dtypes)
# Out:
# HDI rank                                    int64
# Country                                    object
# Human Development Index (HDI)             float64
# Life expectancy at birth                  float64
# Expected years of schooling               float64
# Mean years of schooling                   float64
# Gross national income (GNI) per capita     object
# GNI per capita rank minus HDI rank          int64
# HDI_rank_2020                               int64
# Development_group                          object
# dtype: object

# %%
# I delate the spaces in the GNI column to transform it in float
level1.GNI = level1.GNI.str.replace(' ', '')
level1.GNI = level1.GNI.astype(float)
type(level1.GNI[0])
# Out:
# numpy.float64

# %%
#now level 2
url = 'https://github.com/AntoineDRIGO/PC3/raw/main/level2.csv'

# I read csv precising "," is the way to get decimals
level2 = pd.read_csv(url, sep=';', decimal=',', encoding='ISO-8859-1')
level2 = level2.rename(columns={
    'HDI rank': 'HDI_rank_2021','Human Development Index (HDI)':'HDI','Life expectancy at birth':'Life_expectancy',
    'Expected years of schooling': 'School_level_expected','Mean years of schooling':'Mean_school_level',
    'Gross national income (GNI) per capita':'GNI','GNI per capita rank minus HDI rank': 'GNI_rank'})
level2.GNI = level2.GNI.str.replace(' ', '')
level2.GNI = level2.GNI.astype(float)
level2
# Out:
#     HDI_rank_2021                           Country  \
# 0              67                           Albania
# 1              68                          Bulgaria
# 2              68                           Grenada
# 3              70                          Barbados
# 4              71               Antigua and Barbuda
# 5              72                        Seychelles
# 6              73                         Sri Lanka
# 7              74            Bosnia and Herzegovina
# 8              75             Saint Kitts and Nevis
# 9              76        Iran (Islamic Republic of)
# 10             77                           Ukraine
# 11             78                   North Macedonia
# 12             79                             China
# 13             80                Dominican Republic
# 14             80             Moldova (Republic of)
# 15             80                             Palau
# 16             83                              Cuba
# ...

# %%
#now level 3
url = 'https://github.com/AntoineDRIGO/PC3/raw/main/level3.csv'

# I read csv precising "," is the way to get decimals
level3 = pd.read_csv(url, sep=';', decimal=',', encoding='ISO-8859-1')
level3 = level3.rename(columns={
    'HDI rank': 'HDI_rank_3031','Human Development Index (HDI)':'HDI','Life expectancy at birth':'Life_expectancy',
    'Expected years of schooling': 'School_level_expected','Mean years of schooling':'Mean_school_level',
    'Gross national income (GNI) per capita':'GNI','GNI per capita rank minus HDI rank': 'GNI_rank'})
level3.GNI = level3.GNI.str.replace(' ', '')
level3.GNI = level3.GNI.astype(float)
level3
# Out:
#     HDI_rank_3031                             Country  \
# 0             116                         Philippines
# 1             117                            Botswana
# 2             118    Bolivia (Plurinational State of)
# 3             118                          Kyrgyzstan
# 4             120  Venezuela (Bolivarian Republic of)
# 5             121                                Iraq
# 6             122                          Tajikistan
# 7             123                              Belize
# 8             123                             Morocco
# 9             125                         El Salvador
# 10            126                           Nicaragua
# 11            127                              Bhutan
# 12            128                          Cabo Verde
# 13            129                          Bangladesh
# 14            130                              Tuvalu
# 15            131                    Marshall Islands
# ...

# %%
#now level 4
url = 'https://github.com/AntoineDRIGO/PC3/raw/main/level4.csv' # Changed PC4 to PC3 in the url

# I read csv precising "," is the way to get decimals
level4 = pd.read_csv(url, sep=';', decimal=',', encoding='ISO-8859-1')
level4 = level4.rename(columns={
    'HDI rank': 'HDI_rank_2021','Human Development Index (HDI)':'HDI','Life expectancy at birth':'Life_expectancy',
    'Expected years of schooling': 'School_level_expected','Mean years of schooling':'Mean_school_level',
    'Gross national income (GNI) per capita':'GNI','GNI per capita rank minus HDI rank': 'GNI_rank'})
level4.GNI = level4.GNI.str.replace(' ', '')
level4.GNI = level4.GNI.astype(float)
level4
# Out:
#     HDI_rank_2021                             Country  \
# 0             160       Tanzania (United Republic of)
# 1             161                            Pakistan
# 2             162                                Togo
# 3             163                               Haiti
# 4             163                             Nigeria
# 5             165                              Rwanda
# 6             166                               Benin
# 7             166                              Uganda
# 8             168                             Lesotho
# 9             169                              Malawi
# 10            170                             Senegal
# 11            171                            Djibouti
# 12            172                               Sudan
# 13            173                          Madagascar
# 14            174                              Gambia
# 15            175                            Ethiopia
# ...

# %% [markdown]
# # Segundo: Cuando haya integrado los archivos anteriores, haga un merge entre ese archivo, y el archivo countryCODES.xlsx.

# %%
#now countrycodes
url = 'https://github.com/AntoineDRIGO/PC3/raw/main/countryCodes.csv' # Changed PC4 to PC3 in the url

# I read csv precising "," is the way to get decimals
countryCodes = pd.read_csv(url, sep=';', decimal=',', encoding='ISO-8859-1')
countryCodes
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# ...

# %%
#I join all the HDI database
HDI_db = pd.concat([level1, level2, level3, level4], ignore_index=True)
HDI_db
# Out:
#      HDI_rank_2021                   Country  Human Development Index (HDI)   \
# 0              1.0               Switzerland                           0.962
# 1              2.0                    Norway                           0.961
# 2              3.0                   Iceland                           0.959
# 3              4.0    Hong Kong, China (SAR)                           0.952
# 4              5.0                 Australia                           0.951
# ..             ...                       ...                             ...
# 186          187.0                   Burundi                           0.426
# 187          188.0  Central African Republic                           0.404
# 188          189.0                     Niger                           0.400
# 189          190.0                      Chad                           0.394
# 190          191.0               South Sudan                           0.385
#
# ...

# %%
#I delate specials caracters
HDI_db = HDI_db.applymap(lambda x: ''.join(c for c in str(x) if c.isalnum() or c.isspace()))

# I want to capitalise the entire Country column in HDI_db
HDI_db['Country'] = HDI_db['Country'].str.upper()
HDI_db
# Out:
# <ipython-input-20-92cd6129cb34>:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   HDI_db = HDI_db.applymap(lambda x: ''.join(c for c in str(x) if c.isalnum() or c.isspace()))
#     HDI_rank_2021                   Country Human Development Index (HDI)   \
# 0              10               Switzerland                           0962
# 1              20                    Norway                           0961
# 2              30                   Iceland                           0959
# 3              40       Hong Kong China SAR                           0952
# 4              50                 Australia                           0951
# ..            ...                       ...                            ...
# 186          1870                   Burundi                           0426
# 187          1880  Central African Republic                           0404
# 188          1890                     Niger                             04
# ...

# %%
# I merged th two tables
merged_df = pd.merge(HDI_db, countryCodes, on='Country', how='left')
merged_df
# Out:
#     HDI_rank_2021                   Country Human Development Index (HDI)   \
# 0              10               SWITZERLAND                           0962
# 1              20                    NORWAY                           0961
# 2              30                   ICELAND                           0959
# 3              40       HONG KONG CHINA SAR                           0952
# 4              50                 AUSTRALIA                           0951
# ..            ...                       ...                            ...
# 186          1870                   BURUNDI                           0426
# 187          1880  CENTRAL AFRICAN REPUBLIC                           0404
# 188          1890                     NIGER                             04
# 189          1900                      CHAD                           0394
# 190          1910               SOUTH SUDAN                           0385
#
# ...

# %% [markdown]
# # Tercero: Con los archivos fallecidosCOVID.csv,  haga un reporte mensual de fallecidos. Solo debe mostrar por fila el mes (y año) y cuanto fallecidos hubo en ese mes.

# %%
#now countrycodes
url = 'https://github.com/AntoineDRIGO/PC3/raw/main/fallecidosCOVID.csv' # Changed PC4 to PC3 in the url

# I read csv precising "," is the way to get decimals
covid = pd.read_csv(url, sep=';', decimal=',', encoding='ISO-8859-1')
covid
# Out:
#         FECHA_CORTE  FECHA_FALLECIMIENTO  EDAD_DECLARADA       SEXO  \
# 0          20240317             20220219              63  MASCULINO
# 1          20240317             20210529              74  MASCULINO
# 2          20240317             20210623              72   FEMENINO
# 3          20240317             20210824              85  MASCULINO
# 4          20240317             20210627              46  MASCULINO
# ...             ...                  ...             ...        ...
# 220913     20240317             20200809              77  MASCULINO
# 220914     20240317             20201028              81  MASCULINO
# 220915     20240317             20200515              68   FEMENINO
# 220916     20240317             20210414              66   FEMENINO
# 220917     20240317             20200819              61  MASCULINO
#
#                               CLASIFICACION_DEF DEPARTAMENTO PROVINCIA  \
# 0                          Criterio virolÃ³gico       TUMBES    TUMBES
# ...

# %%
print(covid.dtypes)
# Out:
# FECHA_CORTE              int64
# FECHA_FALLECIMIENTO      int64
# EDAD_DECLARADA           int64
# SEXO                    object
# CLASIFICACION_DEF       object
# DEPARTAMENTO            object
# PROVINCIA               object
# DISTRITO                object
# UBIGEO                 float64
# UUID                   float64
# dtype: object

# %%
# I transform FECH_CORTE of covid on date

covid['FECHA_CORTE'] = pd.to_datetime(covid['FECHA_CORTE'], format='%Y%m%d')
covid['FECHA_FALLECIMIENTO'] = pd.to_datetime(covid['FECHA_FALLECIMIENTO'], format='%Y%m%d')
covid
# Out:
#        FECHA_CORTE FECHA_FALLECIMIENTO  EDAD_DECLARADA       SEXO  \
# 0       2024-03-17          2022-02-19              63  MASCULINO
# 1       2024-03-17          2021-05-29              74  MASCULINO
# 2       2024-03-17          2021-06-23              72   FEMENINO
# 3       2024-03-17          2021-08-24              85  MASCULINO
# 4       2024-03-17          2021-06-27              46  MASCULINO
# ...            ...                 ...             ...        ...
# 220913  2024-03-17          2020-08-09              77  MASCULINO
# 220914  2024-03-17          2020-10-28              81  MASCULINO
# 220915  2024-03-17          2020-05-15              68   FEMENINO
# 220916  2024-03-17          2021-04-14              66   FEMENINO
# 220917  2024-03-17          2020-08-19              61  MASCULINO
#
#                               CLASIFICACION_DEF DEPARTAMENTO PROVINCIA  \
# 0                          Criterio virolÃ³gico       TUMBES    TUMBES
# ...

# %%
#  I create groups of same mounth of FECHA_FALLECIMIENTO and count the number of lines in each groups in mounth_death

monthly_deaths = covid.groupby(covid['FECHA_FALLECIMIENTO'].dt.to_period('M'))['FECHA_FALLECIMIENTO'].count()
print(monthly_deaths)
# Out:
# FECHA_FALLECIMIENTO
# 2020-03      181
# 2020-04     5134
# 2020-05    16363
# 2020-06    17462
# 2020-07    18501
# 2020-08    17668
# 2020-09     8437
# 2020-10     4471
# 2020-11     3229
# 2020-12     3885
# 2021-01    11175
# 2021-02    18645
# 2021-03    20691
# 2021-04    23110
# 2021-05    16692
# 2021-06     7722
# 2021-07     3481
# 2021-08     1850
# 2021-09     1140
# 2021-10     1066
# 2021-11     1107
# 2021-12     1283
# 2022-01     3562
# 2022-02     3503
# 2022-03     1299
# 2022-04      741
# 2022-05      625
# 2022-06      542
# 2022-07     1025
# 2022-08     1429
# 2022-09      892
# 2022-10      429
# 2022-11      272
# 2022-12      423
# 2023-01      371
# 2023-02      287
# 2023-03      295
# 2023-04      337
# 2023-05      323
# 2023-06      291
# 2023-07      258
# 2023-08      249
# 2023-09       60
# 2023-10       26
# 2023-11       33
# 2023-12       40
# 2024-01      249
# 2024-02       62
# 2024-03        2
# ...

# %% [markdown]
# # Cuarto: Use el mismo archivo anterior. Esta vez haga un reporte de fallecidos por mes, pero el tipo de muerte debe estar en columnas separadas.

# %%
# I delete all the special caracters in the columns strings

covid['CLASIFICACION_DEF'] = covid['CLASIFICACION_DEF'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
covid['DEPARTAMENTO'] = covid['DEPARTAMENTO'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
covid['PROVINCIA'] = covid['PROVINCIA'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
covid['DISTRITO'] = covid['DISTRITO'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
covid
# Out:
#        FECHA_CORTE FECHA_FALLECIMIENTO  EDAD_DECLARADA       SEXO  \
# 0       2024-03-17          2022-02-19              63  MASCULINO
# 1       2024-03-17          2021-05-29              74  MASCULINO
# 2       2024-03-17          2021-06-23              72   FEMENINO
# 3       2024-03-17          2021-08-24              85  MASCULINO
# 4       2024-03-17          2021-06-27              46  MASCULINO
# ...            ...                 ...             ...        ...
# 220913  2024-03-17          2020-08-09              77  MASCULINO
# 220914  2024-03-17          2020-10-28              81  MASCULINO
# 220915  2024-03-17          2020-05-15              68   FEMENINO
# 220916  2024-03-17          2021-04-14              66   FEMENINO
# 220917  2024-03-17          2020-08-19              61  MASCULINO
#
#                           CLASIFICACION_DEF DEPARTAMENTO PROVINCIA  \
# 0                        Criterio virolgico       TUMBES    TUMBES
# ...

# %%
# I make me sure that'CLASIFICACION_DEF' no have an infiry of values
print(covid['CLASIFICACION_DEF'].unique())
# Out:
# ['Criterio virolgico' 'Criterio SINADEF'
#  'Criterio investigacin Epidemiolgica' 'Criterio clnico'
#  'Criterio serolgico' 'Criterio radiolgico' 'Criterio nexo epidemiolgico'
#  'NotiCovid' 'sinadef']

# %%
# I create a new column Year_Month_Fallecimiento to group it after
covid['Year_Month_Fallecimiento'] = covid['FECHA_FALLECIMIENTO'].dt.to_period('M')
covid
# Out:
#        FECHA_CORTE FECHA_FALLECIMIENTO  EDAD_DECLARADA       SEXO  \
# 0       2024-03-17          2022-02-19              63  MASCULINO
# 1       2024-03-17          2021-05-29              74  MASCULINO
# 2       2024-03-17          2021-06-23              72   FEMENINO
# 3       2024-03-17          2021-08-24              85  MASCULINO
# 4       2024-03-17          2021-06-27              46  MASCULINO
# ...            ...                 ...             ...        ...
# 220913  2024-03-17          2020-08-09              77  MASCULINO
# 220914  2024-03-17          2020-10-28              81  MASCULINO
# 220915  2024-03-17          2020-05-15              68   FEMENINO
# 220916  2024-03-17          2021-04-14              66   FEMENINO
# 220917  2024-03-17          2020-08-19              61  MASCULINO
#
#                           CLASIFICACION_DEF DEPARTAMENTO PROVINCIA  \
# 0                        Criterio virolgico       TUMBES    TUMBES
# ...

# %%
# I gorup by Year_Month_Fallecimiento and CLASIFICACION_DEF
monthly_report = covid.groupby(['Year_Month_Fallecimiento', 'CLASIFICACION_DEF']).size().unstack(fill_value=0)
monthly_report
# Out:
# CLASIFICACION_DEF         Criterio SINADEF  Criterio clnico  \
# Year_Month_Fallecimiento
# 2020-03                                 35               52
# 2020-04                               1793              541
# 2020-05                               6826             1152
# 2020-06                               5722              670
# 2020-07                               5012              609
# 2020-08                               4589              611
# 2020-09                               1984              475
# 2020-10                               1091              463
# 2020-11                                704              462
# 2020-12                                802              547
# 2021-01                               2190              514
# 2021-02                               4993              501
# 2021-03                               6100              525
# 2021-04                               7450              748
# ...
